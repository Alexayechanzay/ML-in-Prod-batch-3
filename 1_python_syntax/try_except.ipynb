# %%
# Q.1  Safe Calculator 
try: 
    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))
    result = x / y 
except ZeroDivisionError: 
    print("You cannot divide by zero!")
except ValueError: 
    print("Only numbers are allowed")
else:
    print(f" x divided by y {result}")
# Out:
# Only numbers are allowed

# %%
# User Age Validation 
age = int(input("Enter your age: "))
if age <= 0:
    raise ValueError("Age cannot be either zero or negative number")
else:
    print("Valid")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 age = int(input("Enter your age: "))
#       3 if age <= 0:
# ----> 4     raise ValueError("Age cannot be either zero or negative number")
#       5 else:
#       6     print("Valid")
#
# ValueError: Age cannot be either zero or negative number

# %%
# Shopping List (KeyError)
shopping_list = {
    "apple": 2,
    "banana": 1,
    "orange": 3
}
try: 
    choice = input("Enter the item you want to buy: ")
    if choice in shopping_list:
        print(f"Price ${shopping_list[choice]}")
    else:
         raise KeyError("Error Message:")
except KeyError:
        print("We don't see such item.")

# %%
# Multiple exceptions
try:
    x = int(input("Enter a number: "))
    result =  10 / x
except Exception as e:
    print(f"Error Message: {e}")
else:
    print(f"Result: {result}")
# Out:
# Error Message: division by zero

# %%
# Mini Data loader (ML practical)
scores = ["95", "88", "hello", "76", "100", "abc", "90"]
valid_data = list()
for i in scores:
    try: 
        valid_data.append(int(i)) # store valid data only
    except ValueError:
        print(f"Skipping invalid value: {i}")
        
print(f"Valid data: {valid_data}")
# Out:
# Skipping invalid value: hello
# Skipping invalid value: abc
# Valid data: [95, 88, 76, 100, 90]

# %%
# Challenge 
while True:
    try:
        x = input("Enter a positive integer: ")

        if x < 0:
            print("Number must be positive!")
        else:
            print("Thank you")
            break
    except ValueError:
        print("Inavlid input")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Challenge
#       2 while True:
# ----> 3     x = int(input("Enter a positive integer: "))
#       5     # condition
#       6     if type(x) is not int:
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
print(type(1) == int)
print(type(1))
# Out:
# True
# <class 'int'>
